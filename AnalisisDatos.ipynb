# %%
import pandas as pd
import os

# %% [markdown]
# ### Cargando los archivos CSV en una lista

# %%
rutaDirectorio="/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE"
listaCSVs=[]
for archivo in os.listdir(rutaDirectorio):
    if archivo.endswith(".csv"):
        pathCompletoArchivo = os.path.join(rutaDirectorio,archivo)
        listaCSVs.append(pathCompletoArchivo)

listaCSVs[0:10]
# Out:
# ['/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_00-35-08.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_23-40-16.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-02_00-06-30.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_22-52-48.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_23-39-48.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-02_00-09-38.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_23-08-45.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_23-14-17.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_00-19-42.csv',
#  '/home/astroutb/Escritorio/AnalisisDatosUninorte/AnalisisDatosUninorte/Data UNINORTE/Dimensions-Publication-2024-10-01_22-53-04.csv']

# %% [markdown]
# ### Leemos todos los archivos CSV para unirlos todos en un solo DataFrame

# %%
listaDFs=[]
for csv in listaCSVs:
    dfTemp = pd.read_csv(csv,skiprows=1,delimiter=",")
    listaDFs.append(dfTemp)

listaDFs[0]
# Out:
#      Rank  Publication ID                              DOI        PMID PMCID  \
# 0    8378  pub.1041787394        10.1016/j.jcv.2015.05.021  26209372.0   NaN
# 1    7443  pub.1002563454        10.1007/s11356-015-4153-z  25634366.0   NaN
# 2    6996  pub.1021823307     10.1097/rhu.0000000000000318  26513305.0   NaN
# 3    6306  pub.1013854861        10.1016/j.aap.2015.02.016  25746167.0   NaN
# 4    6079  pub.1019062895      10.1016/j.canep.2015.11.005  26599413.0   NaN
# ..    ...             ...                              ...         ...   ...
# 294   168  pub.1017205282       10.1016/j.ejor.2015.02.014         NaN   NaN
# 295   162  pub.1029626648        10.1007/s10479-015-2087-y         NaN   NaN
# 296   160  pub.1058945975      10.1088/0004-637x/809/1/107         NaN   NaN
# 297   160  pub.1009057518     10.1016/j.quageo.2014.12.002         NaN   NaN
# 298   139  pub.1000650043  10.1016/j.gloplacha.2015.05.005         NaN   NaN
#
#                                                  Title  \
# 0    Fatal cases of Chikungunya virus infection in ...
# 1    Assessment of the risk of failure of high volt...
# 2    Report on the First PANLAR Rheumatology Review...
# 3    Mobile phone use while driving: A hybrid model...
# 4    Cancer mortality in Itapúa—A rural province of...
# ..                                                 ...
# 294       Network construction problems with due dates
# 295  Location-coverage models for preventing attack...
# 296               MULTIPLICITY AMONG F-TYPE STARS. II.
# 297  Differences in 10Be concentrations between riv...
# 298  An integrated sequence stratigraphic and chron...
#
#                                               Abstract  \
# 0    Although Chikungunya infection is emerging as ...
# 1    Pollution on electrical insulators is one of t...
# 2    The First PANLAR Rheumatology Review Course wa...
# 3    The analysis of the effects that mobile phone ...
# 4    BACKGROUND: Itapúa is a rural department in Pa...
# ..                                                 ...
# 294  A network needs to be constructed by a server ...
# 295  Interurban roads are constantly used by transi...
# 296  In continuation of our previous study we prese...
# 297  Cosmogenic nuclides in river sediment have bee...
# 298  We present new findings from Pliocene marine s...
#
#                                       Acknowledgements Funding  \
# 0                                                  NaN     NaN
# 1    Authors would like to thank to the Power Syste...     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4                                                  NaN     NaN
# ..                                                 ...     ...
# 294  The work of Igor Averbakh was supported by a g...     NaN
# 295  The authors would like to thank the Associate ...     NaN
# 296  This work has made extensive use of the Catalo...     NaN
# 297  This study was funded by the Agence Nationale ...     NaN
# 298  AcknowledgementsThis research was funded by th...     NaN
#
#                                      Source title  ...  \
# 0                    Journal of Clinical Virology  ...
# 1    Environmental Science and Pollution Research  ...
# 2            JCR Journal of Clinical Rheumatology  ...
# 3                  Accident Analysis & Prevention  ...
# 4                             Cancer Epidemiology  ...
# ..                                            ...  ...
# 294      European Journal of Operational Research  ...
# 295                 Annals of Operations Research  ...
# 296                     The Astrophysical Journal  ...
# 297                      Quaternary Geochronology  ...
# 298                   Global and Planetary Change  ...
#
#                                  Corresponding Authors  \
# 0    Viasus, Diego (Universidad del Norte; Universi...
# 1      Castillo Sierra, Rafael (Universidad del Norte)
# 2                                                  NaN
# 3    Márquez, Luis (Pedagogical and Technological U...
# 4    Pesch, Beate (Institute for Prevention and Occ...
# ..                                                 ...
# 294             Averbakh, Igor (University of Toronto)
# 295  Batta, Rajan (University at Buffalo, State Uni...
# 296                                                NaN
# 297  Carretier, S. (Géosciences Environnement Toulo...
# 298            Tapia, Claudio A. (University of Otago)
#
#                                   Authors Affiliations Times cited  \
# 0    de la Hoz, Juan M. (Universidad del Norte; Uni...          62
# 1    Castillo Sierra, Rafael (Universidad del Norte...          20
# 2    Pineda, Carlos (Instituto Nacional de Rehabili...           9
# 3    Márquez, Luis (Pedagogical and Technological U...          28
# 4    Codas, Manuel (Universidad Nacional de Itapúa)...           3
# ..                                                 ...         ...
# 294  Averbakh, Igor (University of Toronto); Pereir...          20
# 295  Auad, Ramon (Catholic University of the North)...           5
# 296  Fuhrmann, K. (Ruhr University Bochum; Isaac Ne...          15
# 297  Carretier, S. (Géosciences Environnement Toulo...          46
# 298  Tapia, Claudio A. (University of Otago); Wilso...           2
#
#     Recent citations   RCR   FCR Source Linkout  \
# 0                  7  2.38  9.84            NaN
# 1                  2  0.34  2.31            NaN
# 2                  3  0.34  1.98            NaN
# 3                  3  0.68  6.00            NaN
# 4                  0  0.03  0.64            NaN
# ..               ...   ...   ...            ...
# 294                0   NaN  7.02            NaN
# 295                1   NaN  1.07            NaN
# 296                2   NaN  3.70            NaN
# 297                4   NaN  5.26            NaN
# 298                1   NaN  0.19            NaN
#
#                                         Dimensions URL  \
# 0    https://app.dimensions.ai/details/publication/...
# 1    https://app.dimensions.ai/details/publication/...
# 2    https://app.dimensions.ai/details/publication/...
# 3    https://app.dimensions.ai/details/publication/...
# 4    https://app.dimensions.ai/details/publication/...
# ..                                                 ...
# 294  https://app.dimensions.ai/details/publication/...
# 295  https://app.dimensions.ai/details/publication/...
# 296  https://app.dimensions.ai/details/publication/...
# 297  https://app.dimensions.ai/details/publication/...
# 298  https://app.dimensions.ai/details/publication/...
#
#                       Fields of Research (ANZSRC 2020)  \
# 0    32 Biomedical and Clinical Sciences; 3202 Clin...
# 1    31 Biological Sciences; 3103 Ecology; 38 Econo...
# 2    32 Biomedical and Clinical Sciences; 3202 Clin...
# 3    35 Commerce, Management, Tourism and Services;...
# 4    32 Biomedical and Clinical Sciences; 3202 Clin...
# ..                                                 ...
# 294  40 Engineering; 4005 Civil Engineering; 49 Mat...
# 295  35 Commerce, Management, Tourism and Services;...
# 296   51 Physical Sciences; 5101 Astronomical Sciences
# 297  37 Earth Sciences; 3705 Geology; 3709 Physical...
# 298  37 Earth Sciences; 3702 Climate Change Science...
#
#     Sustainable Development Goals
# 0    3 Good Health and Well Being
# 1                             NaN
# 2    3 Good Health and Well Being
# 3    3 Good Health and Well Being
# 4    3 Good Health and Well Being
# ..                            ...
# 294                           NaN
# 295                           NaN
# 296                           NaN
# 297                           NaN
# 298             13 Climate Action
#
# [299 rows x 34 columns]

# %%
dfDataCompleta = pd.concat(listaDFs, ignore_index=True)
dfDataCompleta
# Out:
#        Rank  Publication ID                                        DOI  \
# 0      8378  pub.1041787394                  10.1016/j.jcv.2015.05.021
# 1      7443  pub.1002563454                  10.1007/s11356-015-4153-z
# 2      6996  pub.1021823307               10.1097/rhu.0000000000000318
# 3      6306  pub.1013854861                  10.1016/j.aap.2015.02.016
# 4      6079  pub.1019062895                10.1016/j.canep.2015.11.005
# ...     ...             ...                                        ...
# 41535    20  pub.1034512215                      10.4324/9781315829357
# 41536    19  pub.1098755192  10.1093/acprof:oso/9780190274832.001.0001
# 41537    15  pub.1037186221                      10.1163/9789004322783
# 41538    13  pub.1109615620                      10.4324/9781315456331
# 41539    12  pub.1020640169                  10.1007/978-3-319-29877-1
#
#              PMID PMCID                                              Title  \
# 0      26209372.0   NaN  Fatal cases of Chikungunya virus infection in ...
# 1      25634366.0   NaN  Assessment of the risk of failure of high volt...
# 2      26513305.0   NaN  Report on the First PANLAR Rheumatology Review...
# 3      25746167.0   NaN  Mobile phone use while driving: A hybrid model...
# 4      26599413.0   NaN  Cancer mortality in Itapúa—A rural province of...
# ...           ...   ...                                                ...
# 41535         NaN   NaN  Black Student Politics, Higher Education and A...
# 41536         NaN   NaN                                    An African Volk
# 41537         NaN   NaN           From Tool of Imperialism to African Icon
# 41538         NaN   NaN  The Challenge of Apartheid: UK–South African R...
# 41539         NaN   NaN  Rediscovering the Essentiality of Marketing, P...
#
#                                                 Abstract  \
# 0      Although Chikungunya infection is emerging as ...
# 1      Pollution on electrical insulators is one of t...
# 2      The First PANLAR Rheumatology Review Course wa...
# 3      The analysis of the effects that mobile phone ...
# 4      BACKGROUND: Itapúa is a rural department in Pa...
# ...                                                  ...
# 41535  Black Student Politics, Higher Education and A...
# 41536  Opposition to apartheid was one of the great m...
# 41537  The Stolen Bible analyses Southern African rec...
# 41538                                                NaN
# 41539  This book contains the full proceedings of the...
#
#                                         Acknowledgements Funding  \
# 0                                                    NaN     NaN
# 1      Authors would like to thank to the Power Syste...     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 41535                                                NaN     NaN
# 41536                                                NaN     NaN
# 41537                                                NaN     NaN
# 41538                                                NaN     NaN
# 41539                                                NaN     NaN
#
#                                             Source title  ...  \
# 0                           Journal of Clinical Virology  ...
# 1           Environmental Science and Pollution Research  ...
# 2                   JCR Journal of Clinical Rheumatology  ...
# 3                         Accident Analysis & Prevention  ...
# 4                                    Cancer Epidemiology  ...
# ...                                                  ...  ...
# 41535                                                NaN  ...
# 41536                                                NaN  ...
# 41537                                                NaN  ...
# 41538                                                NaN  ...
# 41539  Developments in Marketing Science: Proceedings...  ...
#
#                                    Corresponding Authors  \
# 0      Viasus, Diego (Universidad del Norte; Universi...
# 1        Castillo Sierra, Rafael (Universidad del Norte)
# 2                                                    NaN
# 3      Márquez, Luis (Pedagogical and Technological U...
# 4      Pesch, Beate (Institute for Prevention and Occ...
# ...                                                  ...
# 41535                                                NaN
# 41536                                                NaN
# 41537                                                NaN
# 41538                                                NaN
# 41539                                                NaN
#
#                                     Authors Affiliations Times cited  \
# 0      de la Hoz, Juan M. (Universidad del Norte; Uni...          62
# 1      Castillo Sierra, Rafael (Universidad del Norte...          20
# 2      Pineda, Carlos (Instituto Nacional de Rehabili...           9
# 3      Márquez, Luis (Pedagogical and Technological U...          28
# 4      Codas, Manuel (Universidad Nacional de Itapúa)...           3
# ...                                                  ...         ...
# 41535                                   Badat, Saleem ()           6
# 41536                                   Miller, Jamie ()          22
# 41537                                 West, Gerald O. ()          26
# 41538                                 Salmon, Patrick ()           0
# 41539                                                NaN           8
#
#       Recent citations   RCR    FCR Source Linkout  \
# 0                    7  2.38   9.84            NaN
# 1                    2  0.34   2.31            NaN
# 2                    3  0.34   1.98            NaN
# 3                    3  0.68   6.00            NaN
# 4                    0  0.03   0.64            NaN
# ...                ...   ...    ...            ...
# 41535                0   NaN   2.41            NaN
# 41536                5   NaN  43.56            NaN
# 41537               16   NaN  33.54            NaN
# 41538                0   NaN   0.00            NaN
# 41539                1   NaN   1.91            NaN
#
#                                           Dimensions URL  \
# 0      https://app.dimensions.ai/details/publication/...
# 1      https://app.dimensions.ai/details/publication/...
# 2      https://app.dimensions.ai/details/publication/...
# 3      https://app.dimensions.ai/details/publication/...
# 4      https://app.dimensions.ai/details/publication/...
# ...                                                  ...
# 41535  https://app.dimensions.ai/details/publication/...
# 41536  https://app.dimensions.ai/details/publication/...
# 41537  https://app.dimensions.ai/details/publication/...
# 41538  https://app.dimensions.ai/details/publication/...
# 41539  https://app.dimensions.ai/details/publication/...
#
#                         Fields of Research (ANZSRC 2020)  \
# 0      32 Biomedical and Clinical Sciences; 3202 Clin...
# 1      31 Biological Sciences; 3103 Ecology; 38 Econo...
# 2      32 Biomedical and Clinical Sciences; 3202 Clin...
# 3      35 Commerce, Management, Tourism and Services;...
# 4      32 Biomedical and Clinical Sciences; 3202 Clin...
# ...                                                  ...
# 41535  39 Education; 3902 Education Policy, Sociology...
# 41536  44 Human Society; 47 Language, Communication a...
# 41537  43 History, Heritage and Archaeology; 4303 His...
# 41538  44 Human Society; 4407 Policy and Administrati...
# 41539  35 Commerce, Management, Tourism and Services;...
#
#       Sustainable Development Goals
# 0      3 Good Health and Well Being
# 1                               NaN
# 2      3 Good Health and Well Being
# 3      3 Good Health and Well Being
# 4      3 Good Health and Well Being
# ...                             ...
# 41535           4 Quality Education
# 41536       10 Reduced Inequalities
# 41537                           NaN
# 41538                           NaN
# 41539                           NaN
#
# [41540 rows x 34 columns]

# %%
dfDataCompleta.set_index("Rank", inplace=True)

# %%
dfDataCompleta.head(5) ##Viendo si se cambiaron los Indices
# Out:
#       Publication ID                           DOI        PMID PMCID  \
# Rank
# 8378  pub.1041787394     10.1016/j.jcv.2015.05.021  26209372.0   NaN
# 7443  pub.1002563454     10.1007/s11356-015-4153-z  25634366.0   NaN
# 6996  pub.1021823307  10.1097/rhu.0000000000000318  26513305.0   NaN
# 6306  pub.1013854861     10.1016/j.aap.2015.02.016  25746167.0   NaN
# 6079  pub.1019062895   10.1016/j.canep.2015.11.005  26599413.0   NaN
#
#                                                   Title  \
# Rank
# 8378  Fatal cases of Chikungunya virus infection in ...
# 7443  Assessment of the risk of failure of high volt...
# 6996  Report on the First PANLAR Rheumatology Review...
# 6306  Mobile phone use while driving: A hybrid model...
# 6079  Cancer mortality in Itapúa—A rural province of...
#
#                                                Abstract  \
# Rank
# 8378  Although Chikungunya infection is emerging as ...
# 7443  Pollution on electrical insulators is one of t...
# 6996  The First PANLAR Rheumatology Review Course wa...
# 6306  The analysis of the effects that mobile phone ...
# 6079  BACKGROUND: Itapúa is a rural department in Pa...
#
#                                        Acknowledgements Funding  \
# Rank
# 8378                                                NaN     NaN
# 7443  Authors would like to thank to the Power Syste...     NaN
# 6996                                                NaN     NaN
# 6306                                                NaN     NaN
# 6079                                                NaN     NaN
#
#                                       Source title Anthology title  ...  \
# Rank                                                                ...
# 8378                  Journal of Clinical Virology             NaN  ...
# 7443  Environmental Science and Pollution Research             NaN  ...
# 6996          JCR Journal of Clinical Rheumatology             NaN  ...
# 6306                Accident Analysis & Prevention             NaN  ...
# 6079                           Cancer Epidemiology             NaN  ...
#
#                                   Corresponding Authors  \
# Rank
# 8378  Viasus, Diego (Universidad del Norte; Universi...
# 7443    Castillo Sierra, Rafael (Universidad del Norte)
# 6996                                                NaN
# 6306  Márquez, Luis (Pedagogical and Technological U...
# 6079  Pesch, Beate (Institute for Prevention and Occ...
#
#                                    Authors Affiliations Times cited  \
# Rank
# 8378  de la Hoz, Juan M. (Universidad del Norte; Uni...          62
# 7443  Castillo Sierra, Rafael (Universidad del Norte...          20
# 6996  Pineda, Carlos (Instituto Nacional de Rehabili...           9
# 6306  Márquez, Luis (Pedagogical and Technological U...          28
# 6079  Codas, Manuel (Universidad Nacional de Itapúa)...           3
#
#       Recent citations   RCR   FCR Source Linkout  \
# Rank
# 8378                 7  2.38  9.84            NaN
# 7443                 2  0.34  2.31            NaN
# 6996                 3  0.34  1.98            NaN
# 6306                 3  0.68  6.00            NaN
# 6079                 0  0.03  0.64            NaN
#
#                                          Dimensions URL  \
# Rank
# 8378  https://app.dimensions.ai/details/publication/...
# 7443  https://app.dimensions.ai/details/publication/...
# 6996  https://app.dimensions.ai/details/publication/...
# 6306  https://app.dimensions.ai/details/publication/...
# 6079  https://app.dimensions.ai/details/publication/...
#
#                        Fields of Research (ANZSRC 2020)  \
# Rank
# 8378  32 Biomedical and Clinical Sciences; 3202 Clin...
# 7443  31 Biological Sciences; 3103 Ecology; 38 Econo...
# 6996  32 Biomedical and Clinical Sciences; 3202 Clin...
# 6306  35 Commerce, Management, Tourism and Services;...
# 6079  32 Biomedical and Clinical Sciences; 3202 Clin...
#
#      Sustainable Development Goals
# Rank
# 8378  3 Good Health and Well Being
# 7443                           NaN
# 6996  3 Good Health and Well Being
# 6306  3 Good Health and Well Being
# 6079  3 Good Health and Well Being
#
# [5 rows x 33 columns]

# %%
for col in dfDataCompleta.columns:
    print(col,end="\n")
# Out:
# Publication ID
# DOI
# PMID
# PMCID
# Title
# Abstract
# Acknowledgements
# Funding
# Source title
# Anthology title
# Book editors
# MeSH terms
# Publication date
# PubYear
# Publication date (online)
# Publication date (print)
# Volume
# Issue
# Pagination
# Open Access
# Publication Type
# Authors
# Authors (Raw Affiliation)
# Corresponding Authors
# Authors Affiliations
# Times cited
# Recent citations
# RCR
# FCR
# Source Linkout
# Dimensions URL
# Fields of Research (ANZSRC 2020)
# Sustainable Development Goals

# %%
dfDataCompleta.isna().sum()
# Out:
# Publication ID                          0
# DOI                                    26
# PMID                                32174
# PMCID                               34465
# Title                                   0
# Abstract                             8314
# Acknowledgements                    29190
# Funding                             33817
# Source title                         7678
# Anthology title                     34286
# Book editors                        33800
# MeSH terms                          36353
# Publication date                        0
# PubYear                                 0
# Publication date (online)            7140
# Publication date (print)            18435
# Volume                              10250
# Issue                               16310
# Pagination                           4342
# Open Access                             0
# Publication Type                        0
# Authors                              2150
# Authors (Raw Affiliation)            2150
# Corresponding Authors               20599
# Authors Affiliations                 2150
# Times cited                             0
# Recent citations                        0
# RCR                                 35943
# FCR                                 19700
# Source Linkout                      14848
# Dimensions URL                          0
# Fields of Research (ANZSRC 2020)    10861
# Sustainable Development Goals       31084
# dtype: int64

# %% [markdown]
# ### Haciendo el filtrado de los datos que no tienen Autores NAN o NA

# %%
dfSinAUthorsNA =dfDataCompleta.dropna(subset=["Authors","Authors (Raw Affiliation)","Authors Affiliations"])

# %%
dfSinAUthorsNA[dfSinAUthorsNA["Authors"].isna()]
# Out:
# Empty DataFrame
# Columns: [Publication ID, DOI, PMID, PMCID, Title, Abstract, Acknowledgements, Funding, Source title, Anthology title, Book editors, MeSH terms, Publication date, PubYear, Publication date (online), Publication date (print), Volume, Issue, Pagination, Open Access, Publication Type, Authors, Authors (Raw Affiliation), Corresponding Authors, Authors Affiliations, Times cited, Recent citations, RCR, FCR, Source Linkout, Dimensions URL, Fields of Research (ANZSRC 2020), Sustainable Development Goals]
# Index: []
#
# [0 rows x 33 columns]

# %%
dfSinAUthorsNA[dfSinAUthorsNA["Authors (Raw Affiliation)"].isna()]
# Out:
# Empty DataFrame
# Columns: [Publication ID, DOI, PMID, PMCID, Title, Abstract, Acknowledgements, Funding, Source title, Anthology title, Book editors, MeSH terms, Publication date, PubYear, Publication date (online), Publication date (print), Volume, Issue, Pagination, Open Access, Publication Type, Authors, Authors (Raw Affiliation), Corresponding Authors, Authors Affiliations, Times cited, Recent citations, RCR, FCR, Source Linkout, Dimensions URL, Fields of Research (ANZSRC 2020), Sustainable Development Goals]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# ### Exportando temporalmente a CSV

# %%
dfSinAUthorsNA.to_csv("DataFrameSinNAN.csv")

# %% [markdown]
# ### Haciendo el filtrado de los datos que solo son de la UNINORTE
